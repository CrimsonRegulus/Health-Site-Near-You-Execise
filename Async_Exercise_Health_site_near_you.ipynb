# %%
# !apt install gdal-bin python-gdal python3-gdal
# !apt install python3-rtree 
# !pip install git+git://github.com/geopandas/geopandas.git
# !pip install descartes
# !pip install folium
# !pip install plotly_express

# %% [markdown]
# # Hands-on: Geospatial Data with `geopandas`
#
# This hands-on will introduce you to `geopandas` which allows you to read in _vector_ spatial data and also visualize it which builds on your tool set for exploratory data analysis and visualization.
#
# If you're interested in knowing how to handle _raster_ data, there's a library called [rasterio](https://rasterio.readthedocs.io/en/stable/).

# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

from shapely.geometry import Point

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# ## Reading Files
#
# `geopandas` is built mainly for vector-based spatial data. It utilizes the [`fiona`](https://fiona.readthedocs.io/en/latest/README.html) library which is capable of reading and writing a variety of GIS-formats.
#
# For this class, we will focus on loading data from **shapefiles and GeoJSON formats**.
#
# The main function to read in these files is `gpd.read_file`.

# %%
gpd.read_file?

# %% [markdown]
# ### Shapefile
#
# Download the geometric administrative boundaries of the Philippines from GADM.
#
# GADM Philippines: https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_PHL_shp.zip
#
# Note that this is a ZIP file. Unzip the main folder to DSDATA and keep the folder structure within as is.

# %%
# Read shapefile
ph = gpd.read_file('DSDATA/gadm36_PHL_1.shp')
ph.head(50)
# Out:
#    GID_0       NAME_0  ... HASC_1                                           geometry
# 0    PHL  Philippines  ...  PH.AB  POLYGON ((120.77473 17.16318, 120.76637 17.159...
# 1    PHL  Philippines  ...  PH.AN  POLYGON ((125.44627 8.66631, 125.44199 8.66333...
# 2    PHL  Philippines  ...  PH.AS  POLYGON ((125.90923 7.99845, 125.90176 7.99794...
# 3    PHL  Philippines  ...  PH.AK  MULTIPOLYGON (((122.42083 11.63194, 122.42000 ...
# 4    PHL  Philippines  ...  PH.AL  MULTIPOLYGON (((123.28764 13.04923, 123.28686 ...
# 5    PHL  Philippines  ...  PH.AQ  MULTIPOLYGON (((121.92085 10.42076, 121.92107 ...
# 6    PHL  Philippines  ...  PH.AP  POLYGON ((121.43056 17.72600, 121.43214 17.724...
# 7    PHL  Philippines  ...  PH.AU  MULTIPOLYGON (((121.57475 15.59574, 121.57412 ...
# 8    PHL  Philippines  ...  PH.BS  MULTIPOLYGON (((121.96861 6.28222, 121.96806 6...
# 9    PHL  Philippines  ...  PH.BA  MULTIPOLYGON (((120.62363 14.36788, 120.62368 ...
# 10   PHL  Philippines  ...  PH.BN  MULTIPOLYGON (((121.78224 20.33896, 121.78306 ...
# 11   PHL  Philippines  ...  PH.BT  MULTIPOLYGON (((121.09610 13.54918, 121.09583 ...
# 12   PHL  Philippines  ...  PH.BG  POLYGON ((120.62601 16.20179, 120.61117 16.204...
# 13   PHL  Philippines  ...  PH.BI  MULTIPOLYGON (((124.33796 11.70725, 124.33758 ...
# 14   PHL  Philippines  ...  PH.BO  MULTIPOLYGON (((123.92167 9.48583, 123.92111 9...
# 15   PHL  Philippines  ...  PH.BK  POLYGON ((125.37480 7.63411, 125.37286 7.63496...
# 16   PHL  Philippines  ...  PH.BU  MULTIPOLYGON (((121.00214 14.73724, 121.00198 ...
# 17   PHL  Philippines  ...  PH.CG  MULTIPOLYGON (((121.41695 18.46305, 121.41695 ...
# 18   PHL  Philippines  ...  PH.CN  MULTIPOLYGON (((123.10680 14.04700, 123.10735 ...
# 19   PHL  Philippines  ...  PH.CS  MULTIPOLYGON (((123.05878 13.49125, 123.05807 ...
# 20   PHL  Philippines  ...  PH.CM  POLYGON ((124.79418 9.13109, 124.79438 9.13116...
# 21   PHL  Philippines  ...  PH.CP  MULTIPOLYGON (((122.90222 11.45917, 122.90222 ...
# 22   PHL  Philippines  ...  PH.CT  MULTIPOLYGON (((124.33555 13.56307, 124.33611 ...
# 23   PHL  Philippines  ...  PH.CV  MULTIPOLYGON (((120.61583 14.26396, 120.61562 ...
# 24   PHL  Philippines  ...  PH.CB  MULTIPOLYGON (((123.38955 9.43467, 123.39031 9...
# 25   PHL  Philippines  ...  PH.CL  MULTIPOLYGON (((125.83264 7.26979, 125.83264 7...
# 26   PHL  Philippines  ...  PH.DV  MULTIPOLYGON (((125.71917 7.00972, 125.71944 7...
# 27   PHL  Philippines  ...  PH.DS  MULTIPOLYGON (((125.48801 5.51522, 125.48912 5...
# 28   PHL  Philippines  ...  PH.DO  MULTIPOLYGON (((126.06885 6.62813, 126.06888 6...
# 29   PHL  Philippines  ...  PH.DI  MULTIPOLYGON (((125.63354 9.92946, 125.63389 9...
# 30   PHL  Philippines  ...  PH.ES  MULTIPOLYGON (((125.64694 10.77917, 125.64722 ...
# 31   PHL  Philippines  ...  PH.GU  MULTIPOLYGON (((122.59803 10.32855, 122.59774 ...
# 32   PHL  Philippines  ...  PH.IF  POLYGON ((120.98116 16.61036, 120.90524 16.595...
# 33   PHL  Philippines  ...  PH.IN  MULTIPOLYGON (((120.41228 17.91453, 120.41189 ...
# 34   PHL  Philippines  ...  PH.IS  MULTIPOLYGON (((120.39095 17.50012, 120.39131 ...
# 35   PHL  Philippines  ...  PH.II  MULTIPOLYGON (((123.33833 11.20306, 123.33861 ...
# 36   PHL  Philippines  ...  PH.IB  MULTIPOLYGON (((122.47040 16.91995, 122.47040 ...
# 37   PHL  Philippines  ...  PH.KA  POLYGON ((121.46043 17.29165, 121.44605 17.293...
# 38   PHL  Philippines  ...  PH.LU  POLYGON ((120.36440 16.26355, 120.36463 16.263...
# 39   PHL  Philippines  ...  PH.LG  POLYGON ((121.17153 14.13810, 121.16483 14.140...
# 40   PHL  Philippines  ...  PH.LN  POLYGON ((123.97399 7.70124, 123.94920 7.70867...
# 41   PHL  Philippines  ...  PH.LS  MULTIPOLYGON (((124.01667 7.63528, 124.01667 7...
# 42   PHL  Philippines  ...  PH.LE  MULTIPOLYGON (((124.74892 10.24652, 124.74855 ...
# 43   PHL  Philippines  ...  PH.MG  MULTIPOLYGON (((124.18305 7.19472, 124.18250 7...
# 44   PHL  Philippines  ...  PH.MQ  MULTIPOLYGON (((122.00154 13.19066, 122.00112 ...
# 45   PHL  Philippines  ...  PH.MB  MULTIPOLYGON (((122.98417 11.71056, 122.98333 ...
# 46   PHL  Philippines  ...  PH.MM  MULTIPOLYGON (((120.97972 14.49306, 120.98000 ...
# 47   PHL  Philippines  ...  PH.MD  MULTIPOLYGON (((123.77724 8.06518, 123.77683 8...
# 48   PHL  Philippines  ...  PH.MN  MULTIPOLYGON (((124.64449 8.49252, 124.64425 8...
# 49   PHL  Philippines  ...  PH.MT  POLYGON ((120.97614 16.92098, 120.96642 16.904...
#
# [50 rows x 11 columns]

# %%
type(ph)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
ax = ph.plot(figsize=(30,20), color="w", edgecolor="dimgray")

ax.axis('off')

# %% [markdown]
# ### GeoJSON
#
# For GeoJSON, you must specify the `driver='GeoJSON'` to the `read_file` function.
#
# The data below is from the Humanitarian Data Exchange. Download it and place it in `DSDATA` as well.
#
# Philippine Health Sites: https://data.humdata.org/dataset/20e5069f-1eb8-465b-98c8-3442a62cd3f0/resource/ca65b30e-02c8-4fad-8771-fb220ddc444f/download/philippines.geojson

# %%
# Read GeoJSON file
healthsites = gpd.read_file('DSDATA/philippines.geojson', driver='GeoJSON')
healthsites.head(20)
# Out:
#         osm_id  ...                                           geometry
# 0   4714668590  ...                         POINT (122.63445 10.94470)
# 1   6489465986  ...                          POINT (124.24163 8.22731)
# 2    775561027  ...  POLYGON ((121.74563 17.65639, 121.74616 17.657...
# 3    497119467  ...                         POINT (121.02008 14.66840)
# 4    601647960  ...  POLYGON ((120.45718 15.80609, 120.45738 15.806...
# 5    678983870  ...                          POINT (123.98877 9.79335)
# 6   8076834059  ...                         POINT (120.56550 14.91256)
# 7    836665474  ...  POLYGON ((123.52054 13.60460, 123.52061 13.604...
# 8   3940989272  ...                         POINT (123.74586 13.13973)
# 9   1018210574  ...                         POINT (121.24557 14.06309)
# 10   164577919  ...  POLYGON ((120.94741 14.80955, 120.94767 14.809...
# 11   118806480  ...  POLYGON ((120.68357 15.03443, 120.68441 15.035...
# 12  4361891690  ...                         POINT (121.03133 14.63151)
# 13   223628093  ...  POLYGON ((123.80724 11.15379, 123.80734 11.153...
# 14  4451774792  ...                         POINT (120.46787 14.86910)
# 15   796284976  ...  POLYGON ((121.05898 14.73862, 121.05904 14.738...
# 16  5242254936  ...                         POINT (120.20332 11.99825)
# 17  7409659390  ...                         POINT (124.98690 11.24049)
# 18  1337361512  ...                         POINT (121.08552 14.59049)
# 19  7328321185  ...                         POINT (121.16338 14.51331)
#
# [20 rows x 38 columns]

# %% [markdown]
# ### CSV
#
# Sometimes we have data in a normal CSV file but it also contains geographic information in different columns. A common example would be having the longitude and latitude in two separate columns. Since we are aware that there is value in having the data as a geometric point, there is a way to convert two columns to a `Point` using `shapely`.
#
# CitiBike Historical Trip Data: https://s3.amazonaws.com/tripdata/index.html
#
# We should already have the a CitiBike trip data file from the previous lab.

# %%
# Read in the data using pandas

citibike = pd.read_csv('DSDATA/202102-citibike-tripdata.csv')
citibike.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           304  2021-02-01 00:04:23.0780  2021-02-01 00:09:27.7920
# 1           370  2021-02-01 00:07:08.8080  2021-02-01 00:13:19.4670
# 2           635  2021-02-01 00:07:55.9390  2021-02-01 00:18:31.0390
# 3           758  2021-02-01 00:08:42.0960  2021-02-01 00:21:20.7820
# 4           522  2021-02-01 00:09:32.6820  2021-02-01 00:18:15.4100
#
#    start station id       start station name  start station latitude  \
# 0              3175  W 70 St & Amsterdam Ave               40.777480
# 1              3154          E 77 St & 3 Ave               40.773142
# 2               502      Henry St & Grand St               40.714211
# 3              3136          5 Ave & E 63 St               40.766368
# 4               505          6 Ave & W 33 St               40.749013
#
#    start station longitude  end station id        end station name  \
# 0               -73.982886            4045  West End Ave & W 60 St
# 1               -73.958562            3725         2 Ave & E 72 St
# 2               -73.981095             411       E 6 St & Avenue D
# 3               -73.971518            3284      E 88 St & Park Ave
# 4               -73.988484            3687         E 33 St & 1 Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.772370             -73.990050   27451  Subscriber
# 1             40.768762             -73.958408   35000  Subscriber
# 2             40.722281             -73.976687   49319  Subscriber
# 3             40.781411             -73.955959   48091    Customer
# 4             40.743227             -73.974498   48596  Subscriber
#
#    birth year  gender
# 0        1996       2
# 1        1991       1
# 2        1980       2
# 3        1969       0
# 4        1988       1

# %%
citibike.shape
# Out:
# (634631, 15)

# %% [markdown]
# Since the data is huge, this might take a long time to run because geometric operations is quite expensive (computationally) on a local machine.

# %%
stations = citibike[['end station longitude', 'end station latitude']]

# %%
stations.drop_duplicates(inplace=True)
stations.shape
# Out:
# /Users/brianesamson/.pyenv/versions/3.7.6/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# (1283, 2)

# %%
# Create the geometry
geometry = [Point(xy) for xy in zip(stations['end station longitude'], 
                                    stations['end station latitude'])]

# Set the crs
crs = {'init': 'epsg:4326'}

# Create the GeoDataFrame from the DataFrame
citi_gdf = gpd.GeoDataFrame(stations, crs=crs, geometry=geometry)
citi_gdf.head()
# Out:
# /Users/brianesamson/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#    end station longitude  end station latitude                    geometry
# 0             -73.990050             40.772370  POINT (-73.99005 40.77237)
# 1             -73.958408             40.768762  POINT (-73.95841 40.76876)
# 2             -73.976687             40.722281  POINT (-73.97669 40.72228)
# 3             -73.955959             40.781411  POINT (-73.95596 40.78141)
# 4             -73.974498             40.743227  POINT (-73.97450 40.74323)

# %% [markdown]
# ## Basic Visualization
#
# With `matplotlib` and `descartes` built into `geopandas`, we can easily plot a `GeoDataFrame` by simply calling the `plot` function. Most of the parameters that come with the `plot` function from `pandas` can also be used here.

# %%
ax = ph.plot(figsize=(15, 18), color='whitesmoke', edgecolor='dimgray')
ax.axis('off')
# Out:
# (116.444486621, 127.08919715899998, 3.7627797585, 21.894300891499995)

# %% [markdown]
# ## Projections
# Different datasets would have different projections to minimize the distortion depending on where they are on the globe. When doing spatial analysis, it is normal to be working with multiple datasets in different formats and different projections depending on how they were collected or how they should be presented.
#
# Let us take the example of the New York City Taxi Zones and CitiBike stations. We already have the CitiBike stations from the example above.
#
# - NYC Taxi Zones: https://s3.amazonaws.com/nyc-tlc/misc/taxi_zones.zip

# %%
taxi = gpd.read_file(os.getenv('DSDATA') + '/taxi_zones/taxi_zones.shp')
taxi.crs
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
ax = taxi.plot(figsize=(15, 15), color='white', edgecolor='k')
citi_gdf.plot(ax=ax, color='dodgerblue', alpha=0.3);

# %%
print('Taxizones CRS', taxi.crs)
print('Citi Bike CRS', citi_gdf.crs)
# Out:
# Taxizones CRS epsg:2263
# Citi Bike CRS +init=epsg:4326 +type=crs

# %%
# First option is to pass a dictionary like how we initialized the citibike dataframe - this is the CRS
citi_gdf = citi_gdf.to_crs({'init': 'epsg:2263'})

# Another is to simply pass the code for the epsg through the epsg parameter
#citi_gdf = citi_gdf.to_crs(epsg=2263)
# Out:
# /Users/brianesamson/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111)
taxi.plot(ax=ax, color='white', edgecolor='dimgray')
citi_gdf.plot(ax=ax, color='dodgerblue', alpha=0.35)
ax.set_title('Citibike Stations NYC Taxi Zones', fontsize=15)
ax.axis('off');

# %% [markdown]
# ## Merging Data
#
# There are two ways we can merge data in GeoPandas:
# 1. Attribute join
# 2. Spatial join

# %% [markdown]
# ### Attribute join
# This is when you merge two datasets based on a common column. Similar to how you would merge two regular `pandas DataFrame`s.
#
# **IMPORTANT**
#
# When merging a `GeoDataFrame` and a `DataFrame`, it is important that the **left** `DataFrame` is the one with the geospatial data. Otherwise, the `GeoDataFrame` will turn into a regular `DataFrame` and lose all the features and functions of a `GeoDataFrame`.
#
# **Data**
# - World Population Data (World Bank): http://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv
# - Countries shapefile: https://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-admin-0-countries/
#
# *Note: The countries shapefile is also available within geopandas through `gpd.datasets.get_path('naturalearth_lowres')` but this data seems to be outdated as it only has 177 rows.*

# %%
# Read in the shapefile from the download
world = gpd.read_file(os.getenv('DSDATA') + '/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp')
world.head()
# Out:
#         featurecla  scalerank  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0  Admin-0 country          5          2  Indonesia    IDN         0      2
# 1  Admin-0 country          5          3   Malaysia    MYS         0      2
# 2  Admin-0 country          6          2      Chile    CHL         0      2
# 3  Admin-0 country          0          3    Bolivia    BOL         0      2
# 4  Admin-0 country          0          2       Peru    PER         0      2
#
#                 TYPE      ADMIN ADM0_A3  ...  NAME_KO    NAME_NL    NAME_PL  \
# 0  Sovereign country  Indonesia     IDN  ...    인도네시아  Indonesië  Indonezja
# 1  Sovereign country   Malaysia     MYS  ...    말레이시아   Maleisië    Malezja
# 2  Sovereign country      Chile     CHL  ...       칠레      Chili      Chile
# 3  Sovereign country    Bolivia     BOL  ...     볼리비아    Bolivia    Boliwia
# 4  Sovereign country       Peru     PER  ...       페루       Peru       Peru
#
#      NAME_PT    NAME_RU     NAME_SV    NAME_TR    NAME_VI NAME_ZH  \
# 0  Indonésia  Индонезия  Indonesien  Endonezya  Indonesia   印度尼西亚
# 1    Malásia   Малайзия    Malaysia    Malezya   Malaysia    马来西亚
# 2      Chile       Чили       Chile       Şili      Chile      智利
# 3    Bolívia    Боливия     Bolivia    Bolivya    Bolivia    玻利維亞
# 4       Peru       Перу        Peru       Peru       Peru      秘鲁
#
#                                             geometry
# 0  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
#
# [5 rows x 95 columns]

# %%
population = pd.read_csv(os.getenv('DSDATA') + '/API_SP.POP.TOTL_DS2_en_csv_v2_2252106/API_SP.POP.TOTL_DS2_en_csv_v2_2252106.csv',
                         skiprows=3)
population.dropna(axis=1, how='all', inplace=True)
print(len(population))
population.head(3)
# Out:
# 264
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
#
#         1961       1962       1963       1964       1965  ...        2010  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101669.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  29185507.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  23356246.0
#
#          2011        2012        2013        2014        2015        2016  \
# 0    102046.0    102560.0    103159.0    103774.0    104341.0    104872.0
# 1  30117413.0  31161376.0  32269589.0  33370794.0  34413603.0  35383128.0
# 2  24220661.0  25107931.0  26015780.0  26941779.0  27884381.0  28842484.0
#
#          2017        2018        2019
# 0    105366.0    105845.0    106314.0
# 1  36296400.0  37172386.0  38041754.0
# 2  29816748.0  30809762.0  31825295.0
#
# [3 rows x 64 columns]

# %%
country_shapes = world[['ADMIN', 'ADM0_A3', 'geometry']]
type(country_shapes)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Merge the two dataframes
# Here I used LEFT JOIN first to be able to get all the country shapes
country_pop = country_shapes.merge(population, left_on='ADM0_A3', right_on='Country Code', how='left')
country_pop.head()
# Out:
#        ADMIN ADM0_A3                                           geometry  \
# 0  Indonesia     IDN  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1   Malaysia     MYS  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2      Chile     CHL  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3    Bolivia     BOL  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4       Peru     PER  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
#
#   Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0    Indonesia          IDN  Population, total    SP.POP.TOTL  87751068.0
# 1     Malaysia          MYS  Population, total    SP.POP.TOTL   8156347.0
# 2        Chile          CHL  Population, total    SP.POP.TOTL   8132990.0
# 3      Bolivia          BOL  Population, total    SP.POP.TOTL   3656955.0
# 4         Peru          PER  Population, total    SP.POP.TOTL  10155015.0
#
#          1961        1962  ...         2010         2011         2012  \
# 0  90098394.0  92518377.0  ...  241834215.0  245116206.0  248452413.0
# 1   8417824.0   8692342.0  ...   28208035.0   28650955.0   29068159.0
# 2   8303811.0   8476897.0  ...   17062536.0   17233576.0   17400347.0
# 3   3728964.0   3802990.0  ...   10048590.0   10212954.0   10377676.0
# 4  10446620.0  10749466.0  ...   29027674.0   29264318.0   29506788.0
#
#           2013         2014         2015         2016         2017  \
# 0  251806402.0  255129004.0  258383256.0  261554226.0  264645886.0
# 1   29468872.0   29866559.0   30270962.0   30684804.0   31105028.0
# 2   17571507.0   17758959.0   17969353.0   18209068.0   18470439.0
# 3   10542376.0   10706517.0   10869730.0   11031813.0   11192854.0
# 4   29773987.0   30090359.0   30470734.0   30926032.0   31444297.0
#
#           2018         2019
# 0  267663435.0  270625568.0
# 1   31528585.0   31949777.0
# 2   18729160.0   18952038.0
# 3   11353142.0   11513100.0
# 4   31989256.0   32510453.0
#
# [5 rows x 67 columns]

# %%
# However, looking at the tail of the dataset, we can see that there are certain areas that have no population data
country_pop.tail()
# Out:
#                             ADMIN ADM0_A3  \
# 250                   Macao S.A.R     MAC
# 251   Ashmore and Cartier Islands     ATC
# 252  Bajo Nuevo Bank (Petrel Is.)     BJN
# 253               Serranilla Bank     SER
# 254              Scarborough Reef     SCR
#
#                                               geometry      Country Name  \
# 250  MULTIPOLYGON (((113.55860 22.16303, 113.56943 ...  Macao SAR, China
# 251  POLYGON ((123.59702 -12.42832, 123.59775 -12.4...               NaN
# 252  POLYGON ((-79.98929 15.79495, -79.98782 15.796...               NaN
# 253  POLYGON ((-78.63707 15.86209, -78.64041 15.864...               NaN
# 254  POLYGON ((117.75389 15.15437, 117.75569 15.151...               NaN
#
#     Country Code     Indicator Name Indicator Code      1960      1961  \
# 250          MAC  Population, total    SP.POP.TOTL  167791.0  170462.0
# 251          NaN                NaN            NaN       NaN       NaN
# 252          NaN                NaN            NaN       NaN       NaN
# 253          NaN                NaN            NaN       NaN       NaN
# 254          NaN                NaN            NaN       NaN       NaN
#
#          1962  ...      2010      2011      2012      2013      2014  \
# 250  176183.0  ...  538219.0  550832.0  564039.0  577372.0  590208.0
# 251       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 252       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 253       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 254       NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#          2015      2016      2017      2018      2019
# 250  602085.0  612836.0  622585.0  631636.0  640445.0
# 251       NaN       NaN       NaN       NaN       NaN
# 252       NaN       NaN       NaN       NaN       NaN
# 253       NaN       NaN       NaN       NaN       NaN
# 254       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 67 columns]

# %%
ax = country_pop.plot(figsize=(15,8), column='2016', cmap=plt.cm.Reds, legend=True, edgecolor='gainsboro')
ax.set_title('Population of the world in 2016', fontsize=15);
ax.axis(False)
# Out:
# (-197.99999999999991, 198.0, -62.89613446679989, 90.61173089680007)

# %%
# Let's drop the rows with NaN's so we can actually see the population distribution arcoss the world
country_pop.dropna(axis=0, how='any', inplace=True)
country_pop.shape
# Out:
# (209, 67)

# %%
ax = country_pop.plot(figsize=(15,8), column='2016', cmap=plt.cm.Reds, legend=True, edgecolor='gainsboro')
ax.set_title('Population of the world in 2016', fontsize=15)
ax.axis('off');

# %% [markdown]
# ### Spatial Join
# Spatial join is already built into `geopandas` through the function `gpd.sjoin()`. The spatial operation is passed through the parameter `op` and the join can also be specified like a merge in `pandas` through the parameter `how`.
#
# The main thing to remember when doing a spatial join is the **order** of the `GeoDataFrame` parameters you pass matters. When you do an `sjoin`, only the geometry of the left `GeoDataFrame` is left in the merged data. So make sure you carefully consider what data you want left behind and it also depends on what question you are trying to answer.

# %%
gpd.sjoin?
# Out:
# Signature:
# gpd.sjoin(
#     left_df,
#     right_df,
#     how='inner',
#     op='intersects',
#     lsuffix='left',
#     rsuffix='right',
# )
# Docstring:
# Spatial join of two GeoDataFrames.
#
# Parameters
# ----------
# left_df, right_df : GeoDataFrames
# how : string, default 'inner'
#     The type of join:
#
#     * 'left': use keys from left_df; retain only left_df geometry column
#     * 'right': use keys from right_df; retain only right_df geometry column
#     * 'inner': use intersection of keys from both dfs; retain only
#       left_df geometry column
# op : string, default 'intersection'
#     Binary predicate, one of {'intersects', 'contains', 'within'}.
#     See http://shapely.readthedocs.io/en/latest/manual.html#binary-predicates.
# lsuffix : string, default 'left'
#     Suffix to apply to overlapping column names (left GeoDataFrame).
# rsuffix : string, default 'right'
#     Suffix to apply to overlapping column names (right GeoDataFrame).
# File:      /anaconda3/envs/datasci/lib/python3.7/site-packages/geopandas/tools/sjoin.py
# Type:      function

# %% [markdown]
# #### Data Cleaning through Spatial Join
# Another useful purpose of a spatial join is to clean out erroneous data or exclude data from the study area. From our previous example of the Citibike stations and NYC taxi zones, we can now remove the erroneous data from the NYC study area.

# %%
# This spatial join will return the points within a polygon
# The basic question answered here is "in which taxi zone is the station located?"
stations_within = gpd.sjoin(citi_gdf, taxi, op='within')
stations_within.head()
# Out:
#      end station longitude  end station latitude  \
# 0               -73.990050              40.77237
# 60              -73.989187              40.77516
# 103             -73.982886              40.77748
# 488             -73.982886              40.77748
# 651             -73.990050              40.77237
#
#                           geometry  index_right  OBJECTID  Shape_Leng  \
# 0    POINT (987005.949 220672.168)          142       143     0.05418
# 60   POINT (987244.869 221688.517)          142       143     0.05418
# 103  POINT (988989.886 222534.387)          142       143     0.05418
# 488  POINT (988989.886 222534.387)          142       143     0.05418
# 651  POINT (987005.949 220672.168)          142       143     0.05418
#
#      Shape_Area                 zone  LocationID    borough
# 0      0.000151  Lincoln Square West         143  Manhattan
# 60     0.000151  Lincoln Square West         143  Manhattan
# 103    0.000151  Lincoln Square West         143  Manhattan
# 488    0.000151  Lincoln Square West         143  Manhattan
# 651    0.000151  Lincoln Square West         143  Manhattan

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111)
taxi.plot(ax=ax, color='white', edgecolor='dimgray')
stations_within.plot(ax=ax, color='dodgerblue', alpha=0.35)
ax.set_title('Citibike Stations on NYC Taxi Zones', fontsize=15)
ax.axis('off');

# %%
# This spatial will return the polygons that contain points
# The basic question answered here is "which taxi zones have citibike stations?"
zones_with_stations = gpd.sjoin(taxi, citi_gdf, op='contains')
zones_with_stations.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area           zone  LocationID    borough  \
# 3         4    0.043567    0.000112  Alphabet City           4  Manhattan
# 3         4    0.043567    0.000112  Alphabet City           4  Manhattan
# 3         4    0.043567    0.000112  Alphabet City           4  Manhattan
# 3         4    0.043567    0.000112  Alphabet City           4  Manhattan
# 3         4    0.043567    0.000112  Alphabet City           4  Manhattan
#
#                                             geometry  index_right  \
# 3  POLYGON ((992073.467 203714.076, 992068.667 20...       112567
# 3  POLYGON ((992073.467 203714.076, 992068.667 20...       174897
# 3  POLYGON ((992073.467 203714.076, 992068.667 20...       613877
# 3  POLYGON ((992073.467 203714.076, 992068.667 20...       342080
# 3  POLYGON ((992073.467 203714.076, 992068.667 20...       442950
#
#    end station longitude  end station latitude
# 3             -73.976687             40.722281
# 3             -73.976687             40.722281
# 3             -73.976687             40.722281
# 3             -73.976687             40.722281
# 3             -73.976687             40.722281

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111)
zones_with_stations.plot(ax=ax, color='white', edgecolor='dimgray')
ax.set_title('Taxi Zones with Stations', fontsize=15)
ax.axis('off');

# %%
print(healthsites.crs)
print(ph.crs)
# Out:
# epsg:4326
# epsg:4326

# %%
fig = plt.figure(figsize=(30, 20))
ax = fig.add_subplot(111)
ph.plot(ax=ax, color='white', edgecolor='dimgray')
healthsites.plot(ax=ax, column="amenity", alpha=0.35, legend=True)
ax.set_title('Health-related Amenities in the Philippines', fontsize=15)
ax.axis('off');

# %%
healthsites.describe(include=np.object)
# Out:
#        osm_type is_in_health_zone   amenity speciality addr_street operator  \
# count     10405             10405     10405      10405       10405    10405
# unique        2                 1         9         98        1668      873
# top        node                    pharmacy
# freq       7481             10405      4078      10043        7014     9311
#
#        water_source insurance staff_doctors contact_number  ... staff_nurses  \
# count         10405     10405         10405          10405  ...        10405
# unique            5         2             2            332  ...            2
# top                                                         ...
# freq           9868     10404         10404          10069  ...        10404
#
#        changeset_user wheelchair   beds    url dispensing healthcare  \
# count           10365      10405  10405  10405      10405      10405
# unique           1667          4      7      2         26         53
# top             GOwin
# freq             1904      10327  10399  10404       9647       6405
#
#        operator_type part_time_beds  \
# count          10405              1
# unique            16              1
# top                               0
# freq            9330              1
#
#                                                      tag
# count                                                  1
# unique                                                 1
# top     drugs, prescription, medical supplies, first-aid
# freq                                                   1
#
# [4 rows x 33 columns]

# %%
healthsites.isna().sum()
# Out:
# osm_id                     0
# osm_type                   0
# completeness               0
# is_in_health_zone          0
# amenity                    0
# speciality                 0
# addr_street                0
# operator                   0
# water_source               0
# changeset_id              40
# insurance                  0
# staff_doctors              0
# contact_number             0
# uuid                       0
# electricity                0
# opening_hours              0
# operational_status         0
# source                     0
# is_in_health_area          0
# health_amenity_type        0
# changeset_version         40
# emergency                  0
# changeset_timestamp       40
# addr_housenumber           0
# addr_postcode              0
# addr_city                  0
# name                       0
# staff_nurses               0
# changeset_user            40
# wheelchair                 0
# beds                       0
# url                        0
# dispensing                 0
# healthcare                 0
# operator_type              0
# part_time_beds         10404
# tag                    10404
# geometry                   0
# dtype: int64

# %%
fig = plt.figure(figsize=(30, 20))
ax = fig.add_subplot(111)

ph.plot(ax=ax, color='white', edgecolor='dimgray')
healthsites.plot(ax=ax, column="amenity", cmap="Paired", alpha=0.35, legend=True)
ax.set_title('Health-related Amenities in the Philippines', fontsize=15)
ax.axis('off');

# %%
mm = ph[ph.NAME_1=="Metropolitan Manila"]
mm.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Exercise
#
# For this individual exercise, your task is to use the PH Administrative Areas and Health Sites datasets, and produce an effective visualization for the following question:
#
# ### How many health-related amenities are there in provinces where you, your family, and your relatives are currently residing in?
#
# In your plot, there should be a minimum of 2 provinces and a maximum of 5 provinces. There should be separate plots for each type of amenity available.

# %%
mm = ph[ph.NAME_1=="Metropolitan Manila"]
batangas = ph[ph.NAME_1=="Batangas"]

healthsites_within_mm = gpd.sjoin(healthsites, mm, op='within')
healthsites_within_batangas = gpd.sjoin(healthsites, batangas, op='within')

#healthsites_within_mm.shape
#healthsites_within_mm.amenity.unique()

pharmacy_mm = healthsites_within_mm[healthsites_within_mm.amenity=="pharmacy"]
doctors_mm = healthsites_within_mm[healthsites_within_mm.amenity=="doctors"]
dentist_mm = healthsites_within_mm[healthsites_within_mm.amenity=="dentist"]
clinic_mm = healthsites_within_mm[healthsites_within_mm.amenity=="clinic"]
hospital_mm = healthsites_within_mm[healthsites_within_mm.amenity=="hospital"]
healthcare_mm = healthsites_within_mm[healthsites_within_mm.amenity=="healthcare"]

pharmacy_batangas = healthsites_within_batangas[healthsites_within_batangas.amenity=="pharmacy"]
doctors_batangas = healthsites_within_batangas[healthsites_within_batangas.amenity=="doctors"]
dentist_batangas = healthsites_within_batangas[healthsites_within_batangas.amenity=="dentist"]
clinic_batangas = healthsites_within_batangas[healthsites_within_batangas.amenity=="clinic"]
hospital_batangas = healthsites_within_batangas[healthsites_within_batangas.amenity=="hospital"]
sf_batangas = healthsites_within_batangas[healthsites_within_batangas.amenity=="social_facility"]

#ax = mm.plot(figsize=(30,20), color="w", edgecolor="dimgray")

# %%
#healthsites_within_batangas.amenity.unique()
# Out:
# array(['pharmacy', 'hospital', 'clinic', 'dentist', '', 'doctors',
#        'social_facility'], dtype=object)

# %%
fig, axs = plt.subplots(4, 3, figsize=(30,20))

#Metropolitan Manila

axs[0, 0].set_title('Pharmacies in Metropolitan Manila', fontsize=15)
mm.plot(ax=axs[0, 0], color="w", edgecolor="dimgray")
pharmacy_mm.plot(ax=axs[0, 0], column="amenity", alpha=0.35, legend=True)

axs[0, 1].set_title('Doctors in Metropolitan Manila', fontsize=15)
mm.plot(ax=axs[0, 1], color="w", edgecolor="dimgray")
doctors_mm.plot(ax=axs[0, 1], column="amenity", alpha=0.35, legend=True)

axs[0, 2].set_title('Dentists in Metropolitan Manila', fontsize=15)
mm.plot(ax=axs[0, 2], color="w", edgecolor="dimgray")
dentist_mm.plot(ax=axs[0, 2], column="amenity", alpha=0.35, legend=True)

axs[1, 0].set_title('Clinics in Metropolitan Manila', fontsize=15)
mm.plot(ax=axs[1, 0], color="w", edgecolor="dimgray")
clinic_mm.plot(ax=axs[1, 0], column="amenity", alpha=0.35, legend=True)

axs[1, 1].set_title('Hospitals in Metropolitan Manila', fontsize=15)
mm.plot(ax=axs[1, 1], color="w", edgecolor="dimgray")
hospital_mm.plot(ax=axs[1, 1], column="amenity", alpha=0.35, legend=True)

axs[1, 2].set_title('Healthcares in Metropolitan Manila', fontsize=15)
mm.plot(ax=axs[1, 2], color="w", edgecolor="dimgray")
healthcare_mm.plot(ax=axs[1, 2], column="amenity", alpha=0.35, legend=True)

#Batangas

axs[2, 0].set_title('Pharmacies in Batangas', fontsize=15)
batangas.plot(ax=axs[2, 0], color="w", edgecolor="dimgray")
pharmacy_batangas.plot(ax=axs[2, 0], column="amenity", alpha=0.35, legend=True)

axs[2, 1].set_title('Doctors in Batangas', fontsize=15)
batangas.plot(ax=axs[2, 1], color="w", edgecolor="dimgray")
doctors_batangas.plot(ax=axs[2, 1], column="amenity", alpha=0.35, legend=True)

axs[2, 2].set_title('Dentists in Batangas', fontsize=15)
batangas.plot(ax=axs[2, 2], color="w", edgecolor="dimgray")
dentist_batangas.plot(ax=axs[2, 2], column="amenity", alpha=0.35, legend=True)

axs[3, 0].set_title('Clinics in Batangas', fontsize=15)
batangas.plot(ax=axs[3, 0], color="w", edgecolor="dimgray")
clinic_batangas.plot(ax=axs[3, 0], column="amenity", alpha=0.35, legend=True)

axs[3, 1].set_title('Hospitals in Batangas', fontsize=15)
batangas.plot(ax=axs[3, 1], color="w", edgecolor="dimgray")
hospital_batangas.plot(ax=axs[3, 1], column="amenity", alpha=0.35, legend=True)

axs[3, 2].set_title('Social Facilities in Batangas', fontsize=15)
batangas.plot(ax=axs[3, 2], color="w", edgecolor="dimgray")
sf_batangas.plot(ax=axs[3, 2], column="amenity", alpha=0.35, legend=True)
